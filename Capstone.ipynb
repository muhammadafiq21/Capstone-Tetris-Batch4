# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammadafiq21/Capstone-Tetris-Batch4/blob/main/Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Load a sample dataset

df = pd.read_csv('/content/drive/MyDrive/Capstone/disease-burden-by-risk-factor.csv')
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       DALYs that are from all causes attributed to low physical activity, in both sexes aged all ages  \
# 0                                            61720.0600
# 1                                            62191.6000
# 2                                            63325.2340
# 3                                            64873.6250
# 4                                            66452.0700
# ...                                                 ...
# 6835                                          7196.8833
# 6836                                          7424.6733
# ...

# %%
df.shape
# Out:
# (6840, 25)

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'DALYs that are from all causes attributed to low physical activity, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to non-exclusive breastfeeding, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to air pollution, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to child wasting, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to high systolic blood pressure, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to high fasting plasma glucose, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to child stunting, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to high body-mass index, in both sexes aged all ages',
#        'DALYs that are from all causes attributed to secondhand smoke, in both sexes aged all ages',
# ...

# %%
df = df.rename(columns={'DALYs that are from all causes attributed to low physical activity, in both sexes aged all ages': 'Low physical activity',
                        'DALYs that are from all causes attributed to non-exclusive breastfeeding, in both sexes aged all ages': 'Non-exclusive breastfeeding',
                        'DALYs that are from all causes attributed to air pollution, in both sexes aged all ages': 'Air pollution (outdoor & indoor)',
                        'DALYs that are from all causes attributed to child wasting, in both sexes aged all ages': 'Child wasting',
                        'DALYs that are from all causes attributed to high systolic blood pressure, in both sexes aged all ages': 'High blood pressure',
                        'DALYs that are from all causes attributed to high fasting plasma glucose, in both sexes aged all ages': 'High blood sugar',
                        'DALYs that are from all causes attributed to child stunting, in both sexes aged all ages': 'Child stunting',
                        'DALYs that are from all causes attributed to high body-mass index, in both sexes aged all ages': 'Obesity',
                        'DALYs that are from all causes attributed to secondhand smoke, in both sexes aged all ages': 'Secondhand smoke',
                        'DALYs that are from all causes attributed to unsafe sanitation, in both sexes aged all ages': 'Unsafe sanitations',
                        'DALYs that are from all causes attributed to unsafe water source, in both sexes aged all ages': 'Unsafe water source',
                        'DALYs that are from all causes attributed to diet low in vegetables, in both sexes aged all ages': 'Diet low in vegetables',
                        'DALYs that are from all causes attributed to diet low in fruits, in both sexes aged all ages': 'Diet low in fruits',
                        'DALYs that are from all causes attributed to diet high in sodium, in both sexes aged all ages': 'Diet high in salt',
                        'DALYs that are from all causes attributed to drug use, in both sexes aged all ages': 'Drug use',
                        'DALYs that are from all causes attributed to household air pollution from solid fuels, in both sexes aged all ages': 'Indoor air pollution',
                        'DALYs that are from all causes attributed to high ldl cholesterol, in both sexes aged all ages': 'High cholesterol',
                        'DALYs that are from all causes attributed to iron deficiency, in both sexes aged all ages': 'Iron deficiency',
                        'DALYs that are from all causes attributed to zinc deficiency, in both sexes aged all ages': 'Zinc deficiency',
                        'DALYs that are from all causes attributed to smoking, in both sexes aged all ages': 'Smoking',
                        'DALYs that are from all causes attributed to vitamin a deficiency, in both sexes aged all ages': 'Vitamin A deficiency',
                        'DALYs that are from all causes attributed to ambient particulate matter pollution, in both sexes aged all ages': 'Outdoor particulate matter pollution',
                        })

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Low physical activity',
#        'Non-exclusive breastfeeding', 'Air pollution (outdoor & indoor)',
#        'Child wasting', 'High blood pressure', 'High blood sugar',
#        'Child stunting', 'Obesity', 'Secondhand smoke', 'Unsafe sanitations',
#        'Unsafe water source', 'Diet low in vegetables', 'Diet low in fruits',
#        'Diet high in salt', 'Drug use', 'Indoor air pollution',
#        'High cholesterol', 'Iron deficiency', 'Zinc deficiency', 'Smoking',
#        'Vitamin A deficiency', 'Outdoor particulate matter pollution'],
#       dtype='object')

# %%
#Data reading, checking dimensions and information of the data
print(df)

print('dimensions:')
print(df.shape)

print('Information:')
df.info()
# Out:
#            Entity Code  Year  Low physical activity  \
# 0     Afghanistan  AFG  1990             61720.0600
# 1     Afghanistan  AFG  1991             62191.6000
# 2     Afghanistan  AFG  1992             63325.2340
# 3     Afghanistan  AFG  1993             64873.6250
# 4     Afghanistan  AFG  1994             66452.0700
# ...           ...  ...   ...                    ...
# 6835     Zimbabwe  ZWE  2015              7196.8833
# 6836     Zimbabwe  ZWE  2016              7424.6733
# 6837     Zimbabwe  ZWE  2017              7655.2163
# 6838     Zimbabwe  ZWE  2018              7862.5596
# 6839     Zimbabwe  ZWE  2019              8126.4062
#
#       Non-exclusive breastfeeding  Air pollution (outdoor & indoor)  \
# 0                      197049.340                        1986290.40
# 1                      222485.780                        2069430.00
# 2                      271585.200                        2298508.20
# ...

# %%
df.isnull().sum()
# Out:
# Entity                                    0
# Code                                    690
# Year                                      0
# Low physical activity                     0
# Non-exclusive breastfeeding               0
# Air pollution (outdoor & indoor)          0
# Child wasting                             0
# High blood pressure                       0
# High blood sugar                          0
# Child stunting                            0
# Obesity                                   0
# Secondhand smoke                          0
# Unsafe sanitations                        0
# Unsafe water source                       0
# Diet low in vegetables                    0
# Diet low in fruits                        0
# Diet high in salt                         0
# Drug use                                  0
# Indoor air pollution                      0
# High cholesterol                          0
# Iron deficiency                           0
# ...

# %%
# Checking for duplicates in the cleaned DataFrame (df2)
duplicates_count = len(df[df.duplicated()])
print("Number of duplicates:", duplicates_count)
# Out:
# Number of duplicates: 0

# %%
filtered_data = df[(df['Entity'].isin(['Brunei', 'Cambodia', 'Indonesia', 'laos', 'Malaysia', 'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Vietnam'])) & (df['Year'] >= 2000)]

# %%
filtered_data
# Out:
#        Entity Code  Year  Low physical activity  Non-exclusive breastfeeding  \
# 820    Brunei  BRN  2000              515.93020                    30.101694
# 821    Brunei  BRN  2001              532.17175                    30.042976
# 822    Brunei  BRN  2002              561.87823                    30.500837
# 823    Brunei  BRN  2003              598.60760                    30.930305
# 824    Brunei  BRN  2004              630.03485                    30.617077
# ...       ...  ...   ...                    ...                          ...
# 6655  Vietnam  VNM  2015            88526.48400                 34107.367000
# 6656  Vietnam  VNM  2016            90183.64000                 31101.135000
# 6657  Vietnam  VNM  2017            92456.84000                 28326.970000
# 6658  Vietnam  VNM  2018            95466.59000                 25726.154000
# 6659  Vietnam  VNM  2019            98695.54000                 23386.018000
#
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Low physical activity',
#        'Non-exclusive breastfeeding', 'Air pollution (outdoor & indoor)',
#        'Child wasting', 'High blood pressure', 'High blood sugar',
#        'Child stunting', 'Obesity', 'Secondhand smoke', 'Unsafe sanitations',
#        'Unsafe water source', 'Diet low in vegetables', 'Diet low in fruits',
#        'Diet high in salt', 'Drug use', 'Indoor air pollution',
#        'High cholesterol', 'Iron deficiency', 'Zinc deficiency', 'Smoking',
#        'Vitamin A deficiency', 'Outdoor particulate matter pollution'],
#       dtype='object')

# %%
filtered_data.to_csv('/content/drive/MyDrive/Capstone/disease-burden-ASEAN.csv')
